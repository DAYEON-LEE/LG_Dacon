# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import re
import warnings
warnings.filterwarnings(action='ignore')
import lightgbm as lgb
from sklearn.metrics import *
from sklearn.model_selection import KFold
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix

# %%
train_err = pd.read_csv('/content/drive/MyDrive/데이콘/data/train_err_data.csv')
train_problem = pd.read_csv('/content/drive/MyDrive/데이콘/data/train_problem_data.csv')
test_err = pd.read_csv('/content/drive/MyDrive/데이콘/data/test_err_data.csv')
sample_submission = pd.read_csv('/content/drive/MyDrive/데이콘/data/sample_submission.csv')

# %%
problem = np.zeros(15000)
problem[train_problem.user_id.unique()-10000] = 1 
problem.shape
# Out:
# (15000,)

# %%
id_error = train_err[['user_id','errtype']].values
error = np.zeros((15000,42))

for person_idx, err in tqdm(id_error):
  error[person_idx-10000,err-1]+=1
error.shape
# Out:
# 100%|██████████| 16554663/16554663 [00:47<00:00, 347746.53it/s]
# (15000, 42)

# %%
problem_df = pd.DataFrame(problem)
problem_df.rename({0:'problem'},axis=1,inplace=True)
problem_df['problem'].value_counts()
# Out:
# 0.0    10000
# 1.0     5000
# Name: problem, dtype: int64

# %%
train_x = error
train_y = problem
print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 42)
# (15000,)

# %%
smote = SMOTE(random_state=0)
x_train_over, y_train_over = smote.fit_sample(train_x,train_y)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트:',x_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 값 분포:\n',pd.Series(y_train_over).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트: (20000, 42) (20000,)
# SMOTE 적용 후 레이블 값 분포:
#  1.0    10000
# 0.0    10000
# dtype: int64

# %%
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
accuracies   = []

threshold = 0.5
# 파라미터 설정
params =      {
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'seed': 1015
                }
#-------------------------------------------------------------------------------------
# 5 Kfold cross validation
k_fold = KFold(n_splits=12, shuffle=True, random_state=42)
for train_idx, val_idx in k_fold.split(x_train_over):

    # split train, validation set
    X = x_train_over[train_idx]
    y = y_train_over[train_idx]
    valid_x = x_train_over[val_idx]
    valid_y = y_train_over[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 1000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 50
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)
    accuracy  = accuracy_score(valid_y,valid_pred)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    accuracies.append(accuracy)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.905156	valid_0's pr_auc: 0.913827
# [40]	valid_0's auc: 0.914372	valid_0's pr_auc: 0.923381
# [60]	valid_0's auc: 0.915938	valid_0's pr_auc: 0.925776
# [80]	valid_0's auc: 0.916335	valid_0's pr_auc: 0.926579
# [100]	valid_0's auc: 0.915931	valid_0's pr_auc: 0.926356
# [120]	valid_0's auc: 0.916233	valid_0's pr_auc: 0.926783
# Early stopping, best iteration is:
# [72]	valid_0's auc: 0.916771	valid_0's pr_auc: 0.92684
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.896695	valid_0's pr_auc: 0.912348
# [40]	valid_0's auc: 0.904529	valid_0's pr_auc: 0.920076
# [60]	valid_0's auc: 0.906748	valid_0's pr_auc: 0.922779
# [80]	valid_0's auc: 0.908503	valid_0's pr_auc: 0.924174
# [100]	valid_0's auc: 0.908134	valid_0's pr_auc: 0.92413
# [120]	valid_0's auc: 0.908174	valid_0's pr_auc: 0.924109
# Early stopping, best iteration is:
# [89]	valid_0's auc: 0.909251	valid_0's pr_auc: 0.924673
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.886579	valid_0's pr_auc: 0.900564
# [40]	valid_0's auc: 0.895057	valid_0's pr_auc: 0.910395
# [60]	valid_0's auc: 0.900026	valid_0's pr_auc: 0.91491
# [80]	valid_0's auc: 0.903226	valid_0's pr_auc: 0.917353
# [100]	valid_0's auc: 0.903345	valid_0's pr_auc: 0.917683
# [120]	valid_0's auc: 0.904489	valid_0's pr_auc: 0.918298
# [140]	valid_0's auc: 0.904189	valid_0's pr_auc: 0.91783
# [160]	valid_0's auc: 0.903822	valid_0's pr_auc: 0.917566
# Early stopping, best iteration is:
# [127]	valid_0's auc: 0.905141	valid_0's pr_auc: 0.918796
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.893019	valid_0's pr_auc: 0.905471
# [40]	valid_0's auc: 0.900437	valid_0's pr_auc: 0.914367
# [60]	valid_0's auc: 0.902608	valid_0's pr_auc: 0.91768
# [80]	valid_0's auc: 0.903447	valid_0's pr_auc: 0.918929
# [100]	valid_0's auc: 0.903763	valid_0's pr_auc: 0.9196
# [120]	valid_0's auc: 0.904367	valid_0's pr_auc: 0.920436
# [140]	valid_0's auc: 0.904502	valid_0's pr_auc: 0.920425
# [160]	valid_0's auc: 0.904298	valid_0's pr_auc: 0.920473
# [180]	valid_0's auc: 0.903894	valid_0's pr_auc: 0.92022
# Early stopping, best iteration is:
# [139]	valid_0's auc: 0.904772	valid_0's pr_auc: 0.920531
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.903476	valid_0's pr_auc: 0.911708
# [40]	valid_0's auc: 0.912622	valid_0's pr_auc: 0.919654
# [60]	valid_0's auc: 0.914494	valid_0's pr_auc: 0.922004
# [80]	valid_0's auc: 0.914146	valid_0's pr_auc: 0.922115
# [100]	valid_0's auc: 0.914597	valid_0's pr_auc: 0.923125
# [120]	valid_0's auc: 0.914246	valid_0's pr_auc: 0.923319
# [140]	valid_0's auc: 0.913938	valid_0's pr_auc: 0.923633
# Early stopping, best iteration is:
# [98]	valid_0's auc: 0.914696	valid_0's pr_auc: 0.923063
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.909078	valid_0's pr_auc: 0.905975
# [40]	valid_0's auc: 0.917742	valid_0's pr_auc: 0.917593
# [60]	valid_0's auc: 0.920357	valid_0's pr_auc: 0.922069
# [80]	valid_0's auc: 0.921544	valid_0's pr_auc: 0.924409
# [100]	valid_0's auc: 0.921166	valid_0's pr_auc: 0.924704
# [120]	valid_0's auc: 0.921263	valid_0's pr_auc: 0.924646
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.921604	valid_0's pr_auc: 0.924721
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.891258	valid_0's pr_auc: 0.90143
# [40]	valid_0's auc: 0.901929	valid_0's pr_auc: 0.912857
# [60]	valid_0's auc: 0.905411	valid_0's pr_auc: 0.915979
# [80]	valid_0's auc: 0.90573	valid_0's pr_auc: 0.916664
# [100]	valid_0's auc: 0.906486	valid_0's pr_auc: 0.917396
# [120]	valid_0's auc: 0.906783	valid_0's pr_auc: 0.917847
# [140]	valid_0's auc: 0.907573	valid_0's pr_auc: 0.91862
# [160]	valid_0's auc: 0.907966	valid_0's pr_auc: 0.91897
# [180]	valid_0's auc: 0.908539	valid_0's pr_auc: 0.919001
# [200]	valid_0's auc: 0.90975	valid_0's pr_auc: 0.920182
# [220]	valid_0's auc: 0.910026	valid_0's pr_auc: 0.920492
# [240]	valid_0's auc: 0.910033	valid_0's pr_auc: 0.920598
# [260]	valid_0's auc: 0.910048	valid_0's pr_auc: 0.920441
# [280]	valid_0's auc: 0.910362	valid_0's pr_auc: 0.920486
# [300]	valid_0's auc: 0.911124	valid_0's pr_auc: 0.921241
# [320]	valid_0's auc: 0.910871	valid_0's pr_auc: 0.921097
# [340]	valid_0's auc: 0.911349	valid_0's pr_auc: 0.921298
# [360]	valid_0's auc: 0.910958	valid_0's pr_auc: 0.92102
# Early stopping, best iteration is:
# [311]	valid_0's auc: 0.911335	valid_0's pr_auc: 0.921546
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.898471	valid_0's pr_auc: 0.900208
# [40]	valid_0's auc: 0.907767	valid_0's pr_auc: 0.910195
# [60]	valid_0's auc: 0.911067	valid_0's pr_auc: 0.913254
# [80]	valid_0's auc: 0.910913	valid_0's pr_auc: 0.913635
# [100]	valid_0's auc: 0.911591	valid_0's pr_auc: 0.914154
# [120]	valid_0's auc: 0.912101	valid_0's pr_auc: 0.914631
# [140]	valid_0's auc: 0.911997	valid_0's pr_auc: 0.915014
# [160]	valid_0's auc: 0.912863	valid_0's pr_auc: 0.915792
# [180]	valid_0's auc: 0.912414	valid_0's pr_auc: 0.915615
# [200]	valid_0's auc: 0.91256	valid_0's pr_auc: 0.915886
# Early stopping, best iteration is:
# [160]	valid_0's auc: 0.912863	valid_0's pr_auc: 0.915792
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.904111	valid_0's pr_auc: 0.905205
# [40]	valid_0's auc: 0.91328	valid_0's pr_auc: 0.915862
# [60]	valid_0's auc: 0.915755	valid_0's pr_auc: 0.918888
# [80]	valid_0's auc: 0.916018	valid_0's pr_auc: 0.919543
# [100]	valid_0's auc: 0.916938	valid_0's pr_auc: 0.92035
# [120]	valid_0's auc: 0.916201	valid_0's pr_auc: 0.919862
# [140]	valid_0's auc: 0.915442	valid_0's pr_auc: 0.918832
# Early stopping, best iteration is:
# [96]	valid_0's auc: 0.917007	valid_0's pr_auc: 0.92014
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.898396	valid_0's pr_auc: 0.902134
# [40]	valid_0's auc: 0.905489	valid_0's pr_auc: 0.90939
# [60]	valid_0's auc: 0.90837	valid_0's pr_auc: 0.912995
# [80]	valid_0's auc: 0.910008	valid_0's pr_auc: 0.914656
# [100]	valid_0's auc: 0.911051	valid_0's pr_auc: 0.915858
# [120]	valid_0's auc: 0.911583	valid_0's pr_auc: 0.916542
# [140]	valid_0's auc: 0.912417	valid_0's pr_auc: 0.91731
# [160]	valid_0's auc: 0.911937	valid_0's pr_auc: 0.916486
# [180]	valid_0's auc: 0.913375	valid_0's pr_auc: 0.918061
# [200]	valid_0's auc: 0.913571	valid_0's pr_auc: 0.9181
# [220]	valid_0's auc: 0.913517	valid_0's pr_auc: 0.918265
# [240]	valid_0's auc: 0.913836	valid_0's pr_auc: 0.918611
# [260]	valid_0's auc: 0.913842	valid_0's pr_auc: 0.918593
# Early stopping, best iteration is:
# [225]	valid_0's auc: 0.913842	valid_0's pr_auc: 0.91875
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.893476	valid_0's pr_auc: 0.91548
# [40]	valid_0's auc: 0.903909	valid_0's pr_auc: 0.924677
# [60]	valid_0's auc: 0.908222	valid_0's pr_auc: 0.928459
# [80]	valid_0's auc: 0.909562	valid_0's pr_auc: 0.929782
# [100]	valid_0's auc: 0.910245	valid_0's pr_auc: 0.930442
# [120]	valid_0's auc: 0.909952	valid_0's pr_auc: 0.930556
# [140]	valid_0's auc: 0.90975	valid_0's pr_auc: 0.930733
# [160]	valid_0's auc: 0.910013	valid_0's pr_auc: 0.931092
# Early stopping, best iteration is:
# [128]	valid_0's auc: 0.910675	valid_0's pr_auc: 0.931216
# ==========================================================
# Training until validation scores don't improve for 50 rounds.
# [20]	valid_0's auc: 0.866565	valid_0's pr_auc: 0.994631
# [40]	valid_0's auc: 0.875815	valid_0's pr_auc: 0.995046
# [60]	valid_0's auc: 0.882869	valid_0's pr_auc: 0.995394
# [80]	valid_0's auc: 0.883169	valid_0's pr_auc: 0.995424
# [100]	valid_0's auc: 0.883319	valid_0's pr_auc: 0.995438
# [120]	valid_0's auc: 0.88384	valid_0's pr_auc: 0.995455
# [140]	valid_0's auc: 0.885448	valid_0's pr_auc: 0.995526
# [160]	valid_0's auc: 0.88699	valid_0's pr_auc: 0.995588
# [180]	valid_0's auc: 0.888365	valid_0's pr_auc: 0.995644
# [200]	valid_0's auc: 0.889685	valid_0's pr_auc: 0.995711
# [220]	valid_0's auc: 0.887988	valid_0's pr_auc: 0.995646
# [240]	valid_0's auc: 0.887156	valid_0's pr_auc: 0.995623
# Early stopping, best iteration is:
# [203]	valid_0's auc: 0.890118	valid_0's pr_auc: 0.995728
# ==========================================================

# %%
print(np.mean(auc_scores))
print(np.mean(precision))
print(np.mean(recall))
print(np.mean(accuracies))
# Out:
# 0.9106728171597444
# 0.9966044142614601
# 0.7291925465838509
# 0.7901985029164637

# %%
test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

# %%
id_error = test_err[['user_id','errtype']].values
test_x = np.zeros((test_user_number,42))
for person_idx, err in tqdm(id_error):
    # person_idx - test_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    test_x[person_idx - test_user_id_min,err - 1] += 1
test_x = test_x.reshape(test_x.shape[0],-1)
print(test_x.shape)
# Out:
# 100%|██████████| 16532648/16532648 [00:48<00:00, 339529.24it/s]
# (14999, 42)

# %%
pred_y_list = []
for model in models:
    pred_y = model.predict(test_x)
    pred_y_list.append(pred_y.reshape(-1,1))
    
pred_ensemble = np.mean(pred_y_list, axis = 0)

# %%
# pred = np.where(pred_ensemble>0.5,1,0)
# pred
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
sample_submission['problem'] = pred_ensemble
sample_submission.tail()
# Out:
#        user_id   problem
# 14994    44994  0.266987
# 14995    44995  0.385795
# 14996    44996  0.679784
# 14997    44997  0.860752
# 14998    44998  0.439538

# %%
sample_submission.to_csv('/content/drive/MyDrive/데이콘/submission/lgb_smote_submission_threshold0.5.csv')
